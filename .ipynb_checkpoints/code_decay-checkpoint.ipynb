# %%
# These are our tools — like importing equipment before starting work
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the CSV file into a "DataFrame" (think of it as an Excel table in Python)
df = pd.read_csv('software_defect_prediction_dataset.csv')

print("✅ Dataset loaded!")
print("Shape:", df.shape)  # rows x columns
df.head()                  # shows first 5 rows
# Out:
# ✅ Dataset loaded!
# Shape: (60000, 23)
#    lines_of_code  cyclomatic_complexity  num_functions  num_classes  \
# 0            910                     12              7           79
# 1           3822                      9            197           72
# 2           3142                     20             99           92
# 3            516                     39             52           79
# 4           4476                     27            162           75
#
#    comment_density  code_churn  developer_experience_years  num_developers  \
# 0             0.59         539                          19               4
# 1             0.30         584                           8               8
# 2             0.11         593                           0               6
# 3             0.18          81                          12              14
# 4             0.21         918                          14               1
#
#    commit_frequency  bug_fix_commits  ...  avg_function_length  \
# 0                23                7  ...                   70
# 1               126              153  ...                  180
# 2               272              177  ...                  152
# 3                16                0  ...                  159
# 4               164              109  ...                  169
#
#    depth_of_inheritance  response_for_class  coupling_between_objects  \
# 0                     1                  54                        27
# 1                     5                  73                        23
# 2                     5                   9                        31
# 3                     9                  23                        12
# 4                     2                  84                         9
#
#    lack_of_cohesion  build_failures  static_analysis_warnings  \
# 0              0.06               3                        20
# 1              0.39               9                       154
# 2              0.08               7                       425
# 3              0.44               2                       339
# 4              0.41               3                       111
#
#    security_vulnerabilities  performance_issues  defect
# 0                        31                  21       1
# 1                        38                  29       1
# 2                        22                   6       1
# 3                        24                  12       1
# 4                        19                   2       1
#
# [5 rows x 23 columns]

# %%
# Let's understand what's inside
print("=== Column Names ===")
print(df.columns.tolist())

print("\n=== Data Types ===")
print(df.dtypes)

print("\n=== Missing Values ===")
print(df.isnull().sum())

print("\n=== Defect Distribution ===")
print(df['defect'].value_counts())
# Out:
# === Column Names ===
# ['lines_of_code', 'cyclomatic_complexity', 'num_functions', 'num_classes', 'comment_density', 'code_churn', 'developer_experience_years', 'num_developers', 'commit_frequency', 'bug_fix_commits', 'past_defects', 'test_coverage', 'duplication_percentage', 'avg_function_length', 'depth_of_inheritance', 'response_for_class', 'coupling_between_objects', 'lack_of_cohesion', 'build_failures', 'static_analysis_warnings', 'security_vulnerabilities', 'performance_issues', 'defect']
#
# === Data Types ===
# lines_of_code                   int64
# cyclomatic_complexity           int64
# num_functions                   int64
# num_classes                     int64
# comment_density               float64
# code_churn                      int64
# developer_experience_years      int64
# num_developers                  int64
# commit_frequency                int64
# bug_fix_commits                 int64
# past_defects                    int64
# test_coverage                 float64
# duplication_percentage        float64
# avg_function_length             int64
# depth_of_inheritance            int64
# response_for_class              int64
# coupling_between_objects        int64
# lack_of_cohesion              float64
# build_failures                  int64
# static_analysis_warnings        int64
# security_vulnerabilities        int64
# performance_issues              int64
# defect                          int64
# dtype: object
#
# === Missing Values ===
# lines_of_code                 0
# cyclomatic_complexity         0
# num_functions                 0
# num_classes                   0
# comment_density               0
# code_churn                    0
# developer_experience_years    0
# num_developers                0
# commit_frequency              0
# bug_fix_commits               0
# past_defects                  0
# test_coverage                 0
# duplication_percentage        0
# avg_function_length           0
# depth_of_inheritance          0
# response_for_class            0
# coupling_between_objects      0
# lack_of_cohesion              0
# build_failures                0
# static_analysis_warnings      0
# security_vulnerabilities      0
# performance_issues            0
# defect                        0
# dtype: int64
#
# === Defect Distribution ===
# defect
# 1    58223
# 0     1777
# Name: count, dtype: int64

# %%
# Let's see how many defective vs non-defective modules we have
sns.countplot(x='defect', hue='defect', data=df, palette='Set2', legend=False)
plt.title('Defective vs Non-Defective Modules')
plt.xlabel('Defect (1 = Yes, 0 = No)')
plt.ylabel('Count')
plt.show()
